# %%
# 想定している仮想環境: py38_torch211_cuda121
print("Hello, Natsuki!")
# Out:
# Hello, Natsuki!

# %%
import numpy as np
import json
import os
import torch

from utils.camera import *
from utils.equirectangular_render import *
from utils.eval_camera import *
from utils.eval_depth import *
from utils.eval_mesh import *
from utils.eval_normal import *
from utils.visualize import *
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
base_dir = '/home/jaxa/takama/NeurIPS2025_DB-Trucks/NeurIPS_data-check/data/'
# scene = 'EmeraldSquare'  # OK
# scene = 'sun_temple'     # OK
# scene = 'sibenik'        # OK?, 上の当たりを要確認
# scene = 'gallery'        # OK
# scene = 'bus'            # OK, バスだけなので使わない
# scene = 'san_miguel'     # OK
# scene = 'street_view'    # OK
# scene = 'sponza'         # OK     
# scene = 'barbershop'
scene = 'classroom'

# depth_path = os.path.join(base_dir, scene, '00000_depth0000.exr')
# normal_path = os.path.join(base_dir, scene, '00000_normal0000.exr')
# depth_path = os.path.join(base_dir, scene, '00001_depth0001.exr')
# normal_path = os.path.join(base_dir, scene, '00001_normal0001.exr')
depth_path = os.path.join(base_dir, scene, '00000_depth0001.exr')
normal_path = os.path.join(base_dir, scene, '00000_normal0001.exr')

depth = np.asarray(read_exr_depth_v2(depth_path)).astype(np.float32)          # classroom
# depth = np.asarray(read_exr_depth(depth_path, scale=1)).astype(np.float32)  # barbershop
visualize_depth(depth, visualize_depth_max=10)
print(depth.shape)

normal = np.asarray(read_exr_normal(normal_path)).astype(np.float32)
visualize_normal(normal)
# Out:
# (200, 400)
